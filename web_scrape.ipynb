# %%
import time

from selenium import webdriver  # Used for opening up a web browser
from selenium.common.exceptions import NoSuchElementException  # Used for when element not found

# %%
def exit_prompt(driver):
    '''
    Tries to click out of sign in prompt from glassdoor or the estimated salarty prompt.
    Sign in prompt does not trigger when page loads, only after a job posting is clicked (does not appear again after clicking X).
    Glassdoor estimated salary pop up also appears occasionally when progressing through job postings.
    '''
    try:
        exit = driver.find_element_by_class_name('modal_closeIcon')
        exit.click()
    except NoSuchElementException:
        pass

# %%
def get_next_page(driver, page_num):
    '''
    Concatenates string argument for clicking on next page and clicks on next page element
    '''
    page_element = '//div[@class="pageContainer"]/button[@data-test="pagination-link-'
    page_element += str(page_num) + '\"' + ']'
    try:
        driver.find_element_by_xpath(page_element).click()
    except NoSuchElementException:
        print('No Page Element Found')
    time.sleep(3)  # Wait for page to load

# %%
def get_data(rows, test=False):
    '''
    Grabs rows of data including:
        - Job name, company name, and job location
        - Job salary and company rating
        - Company information
    '''
    url = 'https://www.glassdoor.com/Job/data-scientist-jobs-SRCH_KO0,14.htm'
    driver = webdriver.Edge()  # Using Edge browser
    driver.get(url)
    all_jobs = []
    # job_count = 1
    job_element_count = 0
    page_num_element = 1
    # job_posts = driver.find_elements_by_class_name('react-job-listing')

    while len(all_jobs) <= rows:  # If less than specified rows.
        print('Current j value: ', job_element_count)
        company_name = ''
        job_name = ''
        location = ''
        job_desc = ''
        salary = ''
        rating = ''
        company_size = ''
        company_type = ''
        company_sector = ''
        year_founded = ''
        company_industry = ''
        company_revenue = ''
        job_posts = driver.find_elements_by_class_name('react-job-listing')  # To prevent element refresh, page document missing
        job_posts[job_element_count].click()
        time.sleep(2)  # Wait to prevent bot detection 
        exit_prompt(driver)  # If estimated salary prompt -> problem right now is if you exit the prompt, you re-read the same job. This is because the prompt pops up, but you don't move onto the next job yet...

        try:  # Attempt at acquiring information
            # Basic Job Information
            company_name = driver.find_element_by_class_name('css-xuk5ye').text.split('\n')[0]
            job_name = driver.find_element_by_class_name('css-1j389vi').text
            location = driver.find_element_by_class_name('css-56kyx5').text
            driver.find_element_by_class_name('css-t3xrds').click()
            job_desc = driver.find_element_by_class_name('jobDescriptionContent').text

            # Salary and Company Rating
            try:  # If salary estimate exists
                salary = driver.find_element_by_class_name('css-1hbqxax').text
            except NoSuchElementException:
                salary = -1
            try:  # If rating exists
                rating = driver.find_element_by_class_name('css-ey2fjr').text
            except:
                rating = -1

            # Company Information
            try: # Separate try except for each company info, or else all will default to -1 if even one piece of information is missing.
                company_size = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[1]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                company_type = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[3]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                company_sector = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[5]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                year_founded = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[2]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                company_industry = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[4]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            try:
                company_revenue = driver.find_element_by_xpath('//div[@id="EmpBasicInfo"]/div[1]/div/div[6]/span[2]').text
            except NoSuchElementException:
                company_size = -1
            all_jobs.append([company_name, job_name, location, job_desc, salary, rating, company_size, company_type, company_sector, year_founded,company_industry, company_revenue])
            if test:  # If testing, then print outputs
                print('Company Name: ', company_name)
                print('Job Name: ', job_name)
                print('Location: ', location)
                print('Job Description: ', job_desc[:20])
                print('Salary:', salary)
                print('Rating:' , rating)
                print('Company Size: ', company_size)
                print('Company Type: ', company_type)
                print('Company Sector: ', company_sector)
                print('Year Founded: ', year_founded)
                print('Company Industry: ', company_industry)
                print('Company Revenue: ', company_revenue)
                print('\n')


        except:
            time.sleep(4)
        
        if len(all_jobs) % 29 == 0:  # If last job on page, move to next page
            job_element_count = -1
            page_num_element += 1
            print('Reached last job on the page')
            get_next_page(driver, page_num_element)
        else:  # Do not reset counters yet
            pass
        job_element_count += 1
        # job_count += 1

    print("Exit While Loop")
    return all_jobs

# %%
may_1_df = get_data(850, test=False)
# Out:
# Current j value:  0
# Company Name:  SparkCognition Government Systems (SGS)
# Job Name:  Data Scientist III
# Location:  Austin, TX
# Job Description:  SparkCognition Gover
# Salary: $82K - $131K (Glassdoor est.)
# Rating: -1
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Public
# Company Industry:
# Company Revenue:
#
#
# Current j value:  1
# Company Name:  Innovative Precision Health
# Job Name:  Senior Data Scientist
# Location:  Remote
# Job Description:  Job Responsibilities
# Salary: Employer Provided Salary:$150K
# Rating: 3.2
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Private
# Company Industry:
# Company Revenue:
#
#
# Current j value:  2
# Company Name:  Hyphen
# Job Name:  Principal Data Scientist
# Location:  Remote
# Job Description:  The Hyphen team is l
# Salary: Employer Provided Salary:$130K - $180K
# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:  3
# Company Name:  Interactive Consulting Services, Inc
# Job Name:  Lead Data Scientist
# Location:  Remote
# Job Description:  Interactive Consulti
# Salary: Employer Provided Salary:$150K - $250K
# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:  4
# Company Name:  Cyient
# Job Name:  Data Scientist
# Location:  Phoenix, AZ
# Job Description:  About the Role:
# The
# Salary: $65K - $128K (Glassdoor est.)
# Rating: 3.4
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Information Technology
# Year Founded:  1991
# Company Industry:  Information Technology Support Services
# Company Revenue:  $100 to $500 million (USD)
#
#
# Current j value:  5
# Company Name:  AdVon Commerce
# Job Name:  Data Scientist
# Location:  Dublin, OH
# Job Description:  AdVon Commerce start
# Salary: Employer Provided Salary:$95K
# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:

# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:  16
# Company Name:  Insurity
# Job Name:  Data Scientist
# Location:  Remote
# Job Description:  Who We Are
# Insurity
# Salary: -1
# Rating: 3.6
# Company Size:  501 to 1000 Employees
# Company Type:  Company - Private
# Company Sector:  Information Technology
# Year Founded:  1971
# Company Industry:  Computer Hardware Development
# Company Revenue:  $100 to $500 million (USD)
#
#
# Current j value:  17
# Company Name:  The Travelers Companies, Inc.
# Job Name:  Data Scientist
# Location:  Hartford, CT
# Job Description:  Company Summary
#
# Tak
# Salary: $78K - $129K (Glassdoor est.)
# Rating: 3.9
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Insurance
# Year Founded:  1853
# Company Industry:  Insurance Carriers
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  18
# Company Name:  John Deere
# Job Name:  Senior Data Scientist, Asset Valuation
# Location:  Johnston, IA
# Job Description:  At John Deere, we ru
# Salary: $66K - $138K (Glassdoor est.)
# Rating: 4.1
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Manufacturing
# Year Founded:  1837
# Company Industry:  Machinery Manufacturing
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  19
# Company Name:  Eteam Infoservices Private Limited
# Job Name:  Data Scientist
# Location:  Remote
# Job Description:  post1
# Remote, must b
# Salary: Employer Provided Salary:$65 - $75 Per Hour
# Rating: 4.2
# Company Size:  5001 to 10000 Employees
# Company Type:  Company - Private
# Company Sector:  Human Resources & Staffing
# Year Founded:  1999
# Company Industry:  Staffing & Subcontracting
# Company Revenue:  $100 to $500 million (USD)
#
#
# Current j value:  20
# Company Name:  Jones Family Office
# Job Name:  Data Scientist
# Location:  Remote
# Job Description:  Who We Are:
# SumerSpo
# Salary: -1
# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:  21
# Company Name:  LeapYear
# Job Name:  Data Scientist
# Location:  Remote
# Job Description:  Please apply here: h
# Salary: Employer Provided Salary:$150K - $200K
# Rating: -1
# Company Size:  -1
# Company Type:
# Company Sector:
# Year Founded:
# Company Industry:
# Company Revenue:
#
#
# Current j value:  22
# Company Name:  Envision
# Job Name:  Geospatial Data Scientist/Engineer
# Location:  Remote
# Job Description:  The primary responsi
# Salary: -1
# Rating: 5.0
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Private
# Company Industry:
# Company Revenue:
#
#
# Current j value:  23
# Company Name:  Envision
# Job Name:  Data Scientist – Customer Analytics
# Location:  Remote
# Job Description:  Write model document
# Salary: -1
# Rating: 5.0
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Private
# Company Industry:
# Company Revenue:
#
#
# Current j value:  24
# Company Name:  Zillow
# Job Name:  Senior Data Scientist, Customer Engagement Analytics
# Location:  Remote
# Job Description:  About the team
# Zillo
# Salary: Employer Provided Salary:$127K - $203K
# Rating: 3.8
# Company Size:  5001 to 10000 Employees
# Company Type:  Company - Public
# Company Sector:  Real Estate
# Year Founded:  2005
# Company Industry:  Real Estate
# Company Revenue:  $1 to $2 billion (USD)
#
#
# Current j value:  25
# Company Name:  Momentum Staffing Group LLC
# Job Name:  Data Scientist
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Transportation & Logistics
# Year Founded:  1928
# Company Industry:  Airlines, Airports & Air Transportation
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  4
# Company Name:  Best Buy
# Job Name:  Data Scientist - Research & Development
# Location:  Richfield, MN
# Job Description:  Best Buy Data & Anal
# Salary: $160K - $175K (Employer est.)
# Rating: 3.7
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Retail & Wholesale
# Year Founded:  1966
# Company Industry:  Consumer Electronics & Appliances Stores
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  5
# Company Name:  Apple
# Job Name:  Data Scientist - Data Insights - Ad Platforms
# Location:  Austin, TX
# Job Description:  Summary
# Posted: Apr
# Salary: $160K - $175K (Employer est.)
# Rating: 4.2
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Information Technology
# Year Founded:  1976
# Company Industry:  Computer Hardware Development
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  6
# Company Name:  Thomson Reuters
# Job Name:  Data Scientist
# Location:  McLean, VA
# Job Description:  *The physical employ
# Salary: $160K - $175K (Employer est.)
# Rating: 3.8
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Information Technology
# Year Founded:  2008
# Company Industry:  Enterprise Software & Network Solutions
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  7
# Company Name:  Ledgent Technology
# Job Name:  Data Scientist (JO-2204-159264)
# Location:  Irvine, CA
# Job Description:  Software company in
# Salary: $160K - $175K (Employer est.)
# Rating: 3.9
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Public
# Company Industry:
# Company Revenue:
#
#
# Current j value:  8
# Company Name:  Zillow
# Job Name:  Sr Data Scientist
# Location:  Remote
# Job Description:  About the team
# About
# Salary: $160K - $175K (Employer est.)
# Rating: 3.8
# Company Size:  5001 to 10000 Employees
# Company Type:  Company - Public
# Company Sector:  Real Estate
# Year Founded:  2005
# Company Industry:  Real Estate
# Company Revenue:  $1 to $2 billion (USD)
#
#
# Current j value:  9
# Company Name:  Intellibee Inc
# Job Name:  Data Scientist Advanced Analytics
# Location:  Denver, CO
# Job Description:  Job Title: Data Scie
# Salary: $160K - $175K (Employer est.)
# Rating: -1
# Company Size:  -1
# Company Type:  Unknown / Non-Applicable
# Company Sector:
# Year Founded:  Company - Public
# Company Industry:
# Company Revenue:
#
#
# Current j value:  10
# Company Name:  The Travelers Companies, Inc.
# Job Name:  Sr Director & Data Scientist
# Location:  Hartford, CT
# Job Description:  Who Are We?
#
# Taking
# Salary: $160K - $175K (Employer est.)
# Rating: 3.9
# Company Size:  10000+ Employees
# Company Type:  Company - Public
# Company Sector:  Insurance
# Year Founded:  1853
# Company Industry:  Insurance Carriers
# Company Revenue:  $10+ billion (USD)
#
#
# Current j value:  11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24568/3606673223.py in <module>
# ----> 1 job_data = get_data(62, test=True)
#
# ~\AppData\Local\Temp/ipykernel_24568/778736878.py in get_data(rows, test)
#      31         job_posts = driver.find_elements_by_class_name('react-job-listing')  # To prevent element refresh, page document missing
#      32         job_posts[job_element_count].click()
# ---> 33         time.sleep(2)  # Wait to prevent bot detection
#      34         exit_prompt(driver)  # If estimated salary prompt -> problem right now is if you exit the prompt, you re-read the same job. This is because the prompt pops up, but you don't move onto the next job yet...
#      35
#
# KeyboardInterrupt:
